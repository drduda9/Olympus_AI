# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_excel('Historical_Matches_Training_Data.xlsx')
data = data.dropna()
print(data.shape)
print(list(data.columns))
# Out:
# (15288, 35)
# ['home_name', 'away_name', 'odds_ft_x', 'date', 'season', 'odds_ft_1', 'odds_ft_2', 'odds_corners_x', 'pre_match_away_ppg', 'pre_match_home_ppg', 'team_a_xg_prematch', 'team_a_corners', 'odds_btts_no', 'odds_ft_1_1', 'odds_ft_2_2', 'odds_btts_yes', 'team_a_shots', 'team_b_shots', 'team_b_xg_prematch', 'team_b_corners', 'pre_match_teamA_overall_ppg', 'pre_match_teamB_overall_ppg', 'homeGoalCount', 'awayGoalCount', 'team_a_shotsOnTarget', 'team_a_possession', 'team_b_shotsOnTarget', 'team_b_red_cards', 'team_a_red_cards', 'team_b_yellow_cards', 'team_a_yellow_cards', 'team_b_possession', 'team_b_cards', 'team_a_cards', 'winner']

# %%
hist_matches = data

# %%
print(hist_matches.isna().sum())
# Out:
# home_name                      0
# away_name                      0
# odds_ft_x                      0
# date                           0
# season                         0
# odds_ft_1                      0
# odds_ft_2                      0
# odds_corners_x                 0
# pre_match_away_ppg             0
# pre_match_home_ppg             0
# team_a_xg_prematch             0
# team_a_corners                 0
# odds_btts_no                   0
# odds_ft_1_1                    0
# odds_ft_2_2                    0
# odds_btts_yes                  0
# team_a_shots                   0
# team_b_shots                   0
# team_b_xg_prematch             0
# team_b_corners                 0
# pre_match_teamA_overall_ppg    0
# pre_match_teamB_overall_ppg    0
# homeGoalCount                  0
# awayGoalCount                  0
# team_a_shotsOnTarget           0
# team_a_possession              0
# team_b_shotsOnTarget           0
# team_b_red_cards               0
# ...

# %%
columns = hist_matches.columns.tolist()
columns
# Out:
# ['home_name',
#  'away_name',
#  'odds_ft_x',
#  'date',
#  'season',
#  'odds_ft_1',
#  'odds_ft_2',
#  'odds_corners_x',
#  'pre_match_away_ppg',
#  'pre_match_home_ppg',
#  'team_a_xg_prematch',
#  'team_a_corners',
#  'odds_btts_no',
#  'odds_ft_1_1',
#  'odds_ft_2_2',
#  'odds_btts_yes',
#  'team_a_shots',
#  'team_b_shots',
#  'team_b_xg_prematch',
#  'team_b_corners',
#  'pre_match_teamA_overall_ppg',
#  'pre_match_teamB_overall_ppg',
#  'homeGoalCount',
#  'awayGoalCount',
#  'team_a_shotsOnTarget',
#  'team_a_possession',
#  'team_b_shotsOnTarget',
#  'team_b_red_cards',
#  'team_a_red_cards',
#  'team_b_yellow_cards',
#  'team_a_yellow_cards',
#  'team_b_possession',
#  'team_b_cards',
#  'team_a_cards',
#  'winner']

# %%
df_home=hist_matches[[ 
 'team_a_xg_prematch',
 'team_a_corners',
 'team_a_shots',
 'pre_match_teamA_overall_ppg',
 'homeGoalCount',
 'team_a_shotsOnTarget',
 'team_a_possession',
 'team_a_cards']]

# %%
df_away=hist_matches[[ 
 'team_b_shots',
 'team_b_xg_prematch',
 'team_b_corners',
 'pre_match_teamB_overall_ppg',
 'awayGoalCount',
 'team_b_shotsOnTarget',
 'team_b_possession',
 'team_b_cards']]

# %%
df = hist_matches[[ 
 'team_b_shots',
 'team_b_xg_prematch',
 'team_b_corners',
 'pre_match_teamA_overall_ppg',
 'awayGoalCount',
 'team_b_shotsOnTarget',
 'team_a_xg_prematch',
 'team_a_corners',
 'team_a_shots',
 'pre_match_teamA_overall_ppg',
 'homeGoalCount',
 'team_a_shotsOnTarget',
 'team_a_possession',
 'team_a_cards',
 'team_b_cards']]

# %%
columns1 = df.columns.tolist()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(12,8), 'figure.dpi':300})

corr = df_home.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\dudad\AppData\Local\Temp\ipykernel_19020\945118039.py:6: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_9bc2c_row0_col0, #T_9bc2c_row1_col1, #T_9bc2c_row2_col2, #T_9bc2c_row3_col3, #T_9bc2c_row4_col4, #T_9bc2c_row5_col5, #T_9bc2c_row6_col6, #T_9bc2c_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_9bc2c_row0_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_9bc2c_row0_col7 {
#   background-color: #4f69d9;
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(12,8), 'figure.dpi':300})

corr = df_away.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\dudad\AppData\Local\Temp\ipykernel_19020\2089102263.py:6: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_28073_row0_col0, #T_28073_row1_col1, #T_28073_row2_col2, #T_28073_row3_col3, #T_28073_row4_col4, #T_28073_row5_col5, #T_28073_row6_col6, #T_28073_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_28073_row0_col1, #T_28073_row3_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_28073_row0_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_28073_row0_col3, #T_28073_row1_col0, #T_28073_row3_col5, #T_28073_row4_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_28073_row0_col4, #T_28073_row6_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_28073_row0_col5 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_28073_row0_col6 {
# ...

# %%
#df1 = df[['FTHG','FTAG', 'HS', 'AS', 'HST', 'AST',
# 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']]
#df1.shape

# %%
df1 = df
df1.head()
# Out:
#    team_b_shots  team_b_xg_prematch  team_b_corners  \
# 0            10                 0.0               4
# 1             5                 0.0               3
# 2             8                 0.0               6
# 3            17                 0.0               9
# 4             3                 0.0               2
#
#    pre_match_teamA_overall_ppg  awayGoalCount  team_b_shotsOnTarget  \
# 0                         1.12              1                     5
# 1                         1.24              1                     0
# 2                         1.59              0                     4
# 3                         1.88              0                     6
# 4                         1.41              0                     0
#
#    team_a_xg_prematch  team_a_corners  team_a_shots  \
# 0                 0.0               7             7
# 1                 0.0               9            12
# 2                 0.0               1             8
# ...

# %%
y1=df1[['homeGoalCount']]
y2=df1[['awayGoalCount']]

# %%
X = df_home.drop(['homeGoalCount'],axis=1)
X1 = df_away.drop(['awayGoalCount'],axis=1)

# %%
#from sklearn.preprocessing import LabelEncoder
# encode class values as integers
#encoder = LabelEncoder()
#encoder.fit(y)
#encoded_Y = encoder.transform(y)
# convert integers to dummy variables (i.e. one hot encoded)
#dummy_y = np_utils.to_categorical(encoded_Y)
seed = np.random.seed(777) #for reproducibility

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size = 0.3, random_state = seed)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y2, test_size = 0.3, random_state = seed)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Input

X_train.shape
# Out:
# (10701, 7)

# %%
y_train.shape
# Out:
# (10701, 1)

# %%
y_train1.shape
# Out:
# (10701, 1)

# %%
X_train1.shape
# Out:
# (10701, 7)

# %%
from keras import models
from keras import layers
from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers
#from keras.layers.normalization import BatchNormalization

# %%
in_dim = X_train.shape[1]
out_dim = y_train.shape[1]
in_dim
# Out:
# 7

# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense

# create model
def model():
        # create model
    model = Sequential()
    model.add(Dense(7, activation='relu', kernel_initializer='normal',input_dim=in_dim))
    model.add(Dense(7, activation='relu', kernel_initializer='normal'))
    model.add(Dense(5, activation='relu', kernel_initializer='normal'))
    model.add(Dense(5, activation='relu', kernel_initializer='normal'))
    model.add(Dense(3, activation='relu', kernel_initializer='normal'))



    # output layer
    model.add(Dense(out_dim))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
##### create estimator
from keras.wrappers.scikit_learn import KerasRegressor

estimator=KerasRegressor(build_fn=model,epochs=50, batch_size=250,verbose=0)
estimator.fit(X_train,y_train)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits = 5, shuffle = True)
results = cross_val_score(estimator, X_test, y_test, cv=kfold)
print("Larger: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Larger: -1.31 (0.49) MSE

# %%
estimator2 = KerasRegressor(build_fn=model,epochs=50, batch_size=250,verbose=0)
estimator2.fit(X_train1,y_train1)

# %%
from sklearn.model_selection import KFold
kfold1 = KFold(n_splits = 5, shuffle = True)
results1 = cross_val_score(estimator2, X_test1, y_test1, cv=kfold1)
print("Larger: %.2f (%.2f) MSE" % (results1.mean(), results1.std()))
# Out:
# Larger: -1.38 (0.38) MSE

# %%
#pip install selenium

# %% [markdown]
# # Let's try backtesting on the current season

# %%
#df2 = pd.read_excel('CS22_Backtest.xlsx')
#df2.head()

# %%
#df2.columns

# %%
#df2_home=df2[[ 
# 'team_a_xg_prematch',
# 'team_a_corners',
# 'team_a_shots',
# 'pre_match_teamA_overall_ppg',
# 'homeGoalCount',
# 'team_a_shotsOnTarget',
# 'team_a_possession',
# 'team_a_cards']]

# %%
#df2_away=df2[[ 
# 'team_b_shots',
# 'team_b_xg_prematch',
# 'team_b_corners',
# 'pre_match_teamB_overall_ppg',
# 'awayGoalCount',
# 'team_b_shotsOnTarget',
# 'team_b_possession',
# 'team_b_cards']]

# %%
#table = df2_home.drop(['homeGoalCount'],axis=1)
#table1 = df2_away.drop(['awayGoalCount'],axis=1)
#table.head()

# %%
#y_pred = estimator.predict(table.astype(numpy.float32))
#y_pred1 = estimator2.predict(table1.astype(numpy.float32))
#y_pred.shape

# %%
#print(y_pred[:5])

# %%
#y_pred_ = pd.DataFrame(y_pred,columns=['pdw','phw','paw'])
#y_pred_

# %%
#df2.shape

# %%
#df2['h_pred'] = y_pred
#df2['a_pred'] = y_pred1
#df2['d_pred'] = np.where(df2.h_pred > df2.a_pred,1,0)

#df2.head()

# %%
#df2.describe()

# %%
#df2.to_excel('fut_preds22_23_backtest.xlsx', index=0)

# %% [markdown]
# # Let's try predicting on the current season

# %%
df2 = pd.read_excel('Soccer_All_Matches.xlsx')
df2.head()
# Out:
#               home_name         away_name       date  homeGoalCount  \
# 0               Watford  Sheffield United 2022-08-01              1
# 1               Sheriff    Viktoria Plzeň 2022-08-02              1
# 2            Ludogorets     Dinamo Zagreb 2022-08-02              1
# 3                Monaco               PSV 2022-08-02              1
# 4  Union Saint-Gilloise           Rangers 2022-08-02              2
#
#    awayGoalCount  pre_match_teamA_overall_ppg  team_a_corners  team_a_cards  \
# 0              0                         1.37           10.26          2.26
# 1              2                         1.33            8.50          2.67
# 2              2                         1.50            9.50          3.50
# 3              1                         0.50           10.50          3.00
# 4              0                         1.80            7.70          2.10
#
#    team_a_shots  team_a_shotsOnTarget  ...  team_a_fouls  team_a_xg_prematch  \
# ...

# %%
df2.columns
# Out:
# Index(['home_name', 'away_name', 'date', 'homeGoalCount', 'awayGoalCount',
#        'pre_match_teamA_overall_ppg', 'team_a_corners', 'team_a_cards',
#        'team_a_shots', 'team_a_shotsOnTarget', 'team_a_possession',
#        'team_a_fouls', 'team_a_xg_prematch', 'pre_match_teamB_overall_ppg',
#        'team_b_corners', 'team_b_cards', 'team_b_shots',
#        'team_b_shotsOnTarget', 'team_b_possession', 'team_b_fouls',
#        'team_b_xg_prematch'],
#       dtype='object')

# %%
df2_home=df2[[ 
 'team_a_xg_prematch',
 'team_a_corners',
 'team_a_shots',
 'pre_match_teamA_overall_ppg',
 'team_a_shotsOnTarget',
 'team_a_possession',
 'team_a_cards']]

# %%
df2_away=df2[[ 
 'team_b_shots',
 'team_b_xg_prematch',
 'team_b_corners',
 'pre_match_teamB_overall_ppg',
 'team_b_shotsOnTarget',
 'team_b_possession',
 'team_b_cards']]

# %%
table = df2_home
table1 = df2_away
table.head()
# Out:
#    team_a_xg_prematch  team_a_corners  team_a_shots  \
# 0                1.42           10.26         11.96
# 1                1.40            8.50         10.67
# 2                1.79            9.50         12.00
# 3                2.74           10.50         24.00
# 4                1.44            7.70         11.10
#
#    pre_match_teamA_overall_ppg  team_a_shotsOnTarget  team_a_possession  \
# 0                         1.37                  4.80                 53
# 1                         1.33                  4.50                 50
# 2                         1.50                  6.17                 49
# 3                         0.50                  6.50                 52
# 4                         1.80                  6.30                 48
#
#    team_a_cards
# 0          2.26
# 1          2.67
# 2          3.50
# 3          3.00
# 4          2.10

# %%
y_pred = estimator.predict(table.astype(numpy.float32))
y_pred1 = estimator2.predict(table1.astype(numpy.float32))
y_pred.shape
# Out:
# (3120,)

# %%
print(y_pred[:5])
# Out:
# [1.1622654 1.1346618 1.436833  1.0752949 1.7596118]

# %%
#y_pred_ = pd.DataFrame(y_pred,columns=['pdw','phw','paw'])
#y_pred_
print(y_pred1[:5])
# Out:
# [1.2279475 1.077179  1.1687055 1.484671  0.729371 ]

# %%
df2.shape
# Out:
# (3120, 21)

# %%
df2['h_pred'] = y_pred
df2['a_pred'] = y_pred1
df2['d_pred'] = np.where(df2.h_pred > df2.a_pred,1,0)

df2.head()
# Out:
#               home_name         away_name       date  homeGoalCount  \
# 0               Watford  Sheffield United 2022-08-01              1
# 1               Sheriff    Viktoria Plzeň 2022-08-02              1
# 2            Ludogorets     Dinamo Zagreb 2022-08-02              1
# 3                Monaco               PSV 2022-08-02              1
# 4  Union Saint-Gilloise           Rangers 2022-08-02              2
#
#    awayGoalCount  pre_match_teamA_overall_ppg  team_a_corners  team_a_cards  \
# 0              0                         1.37           10.26          2.26
# 1              2                         1.33            8.50          2.67
# 2              2                         1.50            9.50          3.50
# 3              1                         0.50           10.50          3.00
# 4              0                         1.80            7.70          2.10
#
#    team_a_shots  team_a_shotsOnTarget  ...  team_b_corners  team_b_cards  \
# ...

# %%
df2.describe()
# Out:
#        homeGoalCount  awayGoalCount  pre_match_teamA_overall_ppg  \
# count    3120.000000    3120.000000                  3120.000000
# mean        1.471474       1.158013                     1.357603
# std         1.335324       1.142198                     0.459250
# min         0.000000       0.000000                     0.000000
# 25%         0.000000       0.000000                     1.060000
# 50%         1.000000       1.000000                     1.340000
# 75%         2.000000       2.000000                     1.640000
# max         9.000000       7.000000                     2.500000
#
#        team_a_corners  team_a_cards  team_a_shots  team_a_shotsOnTarget  \
# count     3120.000000   3120.000000   3120.000000           3120.000000
# mean         9.573385      2.224577     12.658968              5.317083
# std          0.979955      0.516535      2.146381              1.072723
# min          2.500000      0.200000      4.500000              1.500000
# ...

# %%
df2.to_excel('fut_preds22_23_new.xlsx', index=0)
